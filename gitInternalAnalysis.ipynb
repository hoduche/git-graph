# %%
# %load_ext autoreload
# %autoreload 2
# %autosave 0
import git_graph as gg

# %%
for each_git_file in gg.get_git_files():
    print(each_git_file)

# %%
print(gg.get_git_file_type('73eab88'))
print(gg.get_git_file_type('9aca930'))

# %%
for each_line in gg.read_git_file('9aca930'):
    print(each_line)

# %%
blobs, trees, commits = gg.build_git_nodes()
print('blobs: ' + str(blobs))
print('trees: ' + str(trees))
print('commits: ' + str(commits))

# %%
graph = gg.GitGraph()
digraph = graph.get_graph()
print(digraph)
with open('auto.dot', 'w+') as digraph_file:
    digraph_file.write(digraph)

# %%
pygraphviz.

# %%
import graphviz
ps = graphviz.Digraph(name='pet-shop', node_attr={'shape': 'plaintext'})
#ps.node('parrot')
#ps.node('dead')
ps.edge('norvegian', 'blue')
ps

# %%
print(ps)
# Out:
# digraph "pet-shop" {
# 	node [shape=plaintext]
# 	norvegian -> blue
# }
